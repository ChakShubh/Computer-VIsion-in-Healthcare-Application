# %% [markdown]
# # LAB ASSIGNMENT

# %% [markdown]
# **Name:** SHUBHADIP CHAKRABARTI

# %% [markdown]
# **Registration Number:** 19BAI1113

# %% [markdown]
# **Objectives:**
#
# We have the following two parts to be accomplished in this Exercise.
#
# PART 1
#
#     1. To Implement the following Machine Leaning Classification Algorithms on the given Image Dataset:
#         a. Logistic Regression
#         b. Gaussian Naive Bayes Classifier
#         c. K Nearest Neighbor
#         d. Random Forest Classifier
#     2. Evaluate the Performance of the each Classification Algorithm using Confusion Matrix and ROC Curve
#     3. Identify the best classifier algorithm on the given dataset.
#
# PART 2
#
#     1. Apply necessary pre-processing techniques and identify possible enhancement methods to increase the accuracy of your the classifier.
#     2. Identify the Best Classifier on the given dataset by comparing the accuracy value obtained in various cases.

# %% [markdown]
# **Dataset Used**: Retinal Diseases Prediction Dataset (Image Dataset - 1000 Images from 39 different Retinal Diseases)

# %% [markdown]
# **Dataset Procurement Source:** The dataset used in this notebook is procured from Kaggle Website

# %% [markdown]
# ### Importing Necessary Modules and Functions

# %%
#import OS
import os

#import numpy
import numpy as np

#import pandas
import pandas as pd

#import seaborn
import seaborn as sb

#import matplotlib
import matplotlib.pyplot as plt

#import train_test_split
from sklearn.model_selection import train_test_split

#import LinearSVC
from sklearn.svm import LinearSVC

#import metrics
from sklearn.metrics import confusion_matrix, accuracy_score, roc_curve, log_loss, precision_recall_curve, f1_score, auc

#import OpenCV
import cv2

# %% [markdown]
# Having imported all the necessary functions into the Notebook, we now move on to the execution of the first part.

# %% [markdown]
# # PART 1: IMPLEMENT CLASSIFICATION ALGORITHMS ON IMAGE DATASET

# %% [markdown]
# ## Importing Dataset into the Notebook

# %%
#Importing the Dataset
#Path of the Dataset Folder
DATADIR = 'C:\\Users\\admin\\Desktop\\Anaconda_Machine Learning\\Computer Vision in Healthcare Application\\Lab 9_Image Classification using Machine Learning\\Dataset'

#Different Classes in the Image Dataset
CATEGORIES = ['1.0.DR2','0.2.Large optic cup']

#Image Size Defined
IMG_SIZE=100

# %% [markdown]
# ## Analyzing the Dataset

# %%
#Display an image
for category in CATEGORIES:
    path=os.path.join(DATADIR, category)
    for img in os.listdir(path):
        img_array=cv2.imread(os.path.join(path,img))
        plt.imshow(img_array)
        plt.show()
        break
    break

# %% [markdown]
# ## Modelling

# %%
training_data=[]
def create_training_data():
    for category in CATEGORIES:
        path=os.path.join(DATADIR, category)
        class_num=CATEGORIES.index(category)
        for img in os.listdir(path):
            try:
                img_array=cv2.imread(os.path.join(path,img))
                new_array=cv2.resize(img_array,(IMG_SIZE,IMG_SIZE))
                training_data.append([new_array,class_num])
            except Exception as e:
                pass
create_training_data()

# %%
#total number of images
print(len(training_data))
# Out:
# 99

# %%
lenofimage = len(training_data)

# %%
X=[]
y=[]

for categories, label in training_data:
    X.append(categories)
    y.append(label)
X= np.array(X).reshape(lenofimage,-1)

# %%
X.shape
# Out:
# (99, 30000)

# %%
X = X/255.0

# %%
X[1]
# Out:
# array([0.00392157, 0.00392157, 0.00392157, ..., 0.        , 0.        ,
#        0.        ])

# %%
y=np.array(y)

# %%
y.shape
# Out:
# (99,)

# %% [markdown]
# ### Train Test Split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y)

# %% [markdown]
# ### Fitting the Model

# %%
from sklearn.svm import SVC
svc = SVC(kernel='linear',gamma='auto')
svc.fit(X_train, y_train)
# Out:
# SVC(gamma='auto', kernel='linear')

# %%
y2 = svc.predict(X_test)

# %% [markdown]
# ### Model Performance

# %%
print("Accuracy on unknown data is",accuracy_score(y_test,y2))
# Out:
# Accuracy on unknown data is 0.96

# %% [markdown]
# ## Inference

# %% [markdown]
#     We could successfully apply SVM Classifier Model on the Retinal Disease Image Dataset.
#     We observe that we could successfully obtain an accuracy of 96% on the two considered classes of the Retinal Disease Image Dataset

# %% [markdown]
# We now implement SVM on Face Expression Recognition Dataset

# %% [markdown]
# # TASK 3: SVM on Face Expression Recognition Dataset

# %% [markdown]
# ## Importing the Dataset

# %% [markdown]
# We now import all the classes of the Face Expression Recognition Dataset and apply SVM Classifier Model on the same.

# %%
#Import Dataset
#Path to the Face Expression Recognition Dataset
DATADIR = 'C:\\Users\\admin\\Desktop\\Anaconda_Machine Learning\\Computer Vision in Healthcare Application\\Lab 6_SVM\\face_detection\\images\\validation'

#The different classes of the Facial Recognition Dataset
CATEGORIES = ['angry','disgust','fear','happy','neutral','sad','surprise']

#Image Size Defined
IMG_SIZE=100

# %% [markdown]
# ## Analyzing the Dataset

# %%
for category in CATEGORIES:
    path=os.path.join(DATADIR, category)
    for img in os.listdir(path):
        img_array=cv2.imread(os.path.join(path,img))
        plt.imshow(img_array)
        plt.show()
        break
    break

# %% [markdown]
# ## Modelling

# %%
training_data=[]

def create_training_data():
    for category in CATEGORIES:
        path=os.path.join(DATADIR, category)
        class_num=CATEGORIES.index(category)
        for img in os.listdir(path):
            try:
                img_array=cv2.imread(os.path.join(path,img))
                new_array=cv2.resize(img_array,(IMG_SIZE,IMG_SIZE))
                training_data.append([new_array,class_num])
            except Exception as e:
                pass
            
create_training_data()

# %%
print(len(training_data))
# Out:
# 7066

# %%
lenofimage = len(training_data)

# %%
X=[]
y=[]

for categories, label in training_data:
    X.append(categories)
    y.append(label)
X= np.array(X).reshape(lenofimage,-1)
##X = tf.keras.utils.normalize(X, axis = 1)

# %%
X.shape
# Out:
# (7066, 30000)

# %%
X = X/255.0

# %%
X[1]
# Out:
# array([0.09019608, 0.09019608, 0.09019608, ..., 0.99215686, 0.99215686,
#        0.99215686])

# %%
y=np.array(y)

# %%
y.shape
# Out:
# (7066,)

# %% [markdown]
# ### Train Test Split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y)

# %% [markdown]
# ### Fitting Model

# %%
from sklearn.svm import SVC
svc = SVC(kernel='linear',gamma='auto')
svc.fit(X_train, y_train)
# Out:
# SVC(gamma='auto', kernel='linear')

# %%
y2 = svc.predict(X_test)

# %% [markdown]
# ### Model Performance

# %%
print("Accuracy on unknown data is",accuracy_score(y_test,y2))
# Out:
# Accuracy on unknown data is 0.300509337860781

# %% [markdown]
# ## Inference

# %% [markdown]
#     We could successfully apply SVM Classifier Model on the Facial Expression Recognition Dataset
#     We observe that we obtain an accuracy of 30.05% on the Facial Expression Recognition Image Dataset

# %% [markdown]
# ## Conclusion

# %% [markdown]
# We could acheive the following objectives in this exercise

# %% [markdown]
#     1. Implementation of SVM Classification task on three different types of Datasets. The datasets were:
#         a. Medical Numerical Dataset (Binary Classification)
#         b. Retinal Disease Image Dataset (Binary Classification)
#         c. Facial Expression Recognition Dataset (Multiclass Classification)
#
#     2. After successful application of SVM Classifier Model, we could successfully achieve the following accuracies for the three datasets:
#         a. Heart Attack Prediction Dataset (Numerical; Binary Classification) - 72.46%
#         b. Retinal Disease Image Dataset (Binary Classification) - 96%
#         c. Facial Expression Recognition Dataset (Multiclass Classification) - 30.05%
